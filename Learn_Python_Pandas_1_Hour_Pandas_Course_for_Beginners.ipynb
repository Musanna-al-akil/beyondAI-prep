# %% [markdown]
# <a href="https://colab.research.google.com/github/Musanna-al-akil/beyondAI-prep/blob/master/Learn_Python_Pandas_1_Hour_Pandas_Course_for_Beginners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
s1=pd.Series()
# Out:
# Series([], dtype: object)

# %%
s1
# Out:
# Series([], dtype: object)

# %%
s2 = pd.Series([1,2,3,4,5])

# %%
s2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s2.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s2.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
s3 = pd.Series([1,2,3,4,5],index=[10,20,30,40,50])
s3
# Out:
# 10    1
# 20    2
# 30    3
# 40    4
# 50    5
# dtype: int64

# %%
scores = pd.Series([3.2,4.5,2.6,4,3],index = ['bob','gorge','alex','fib','alex'])

# %%
scores.index
# Out:
# Index(['bob', 'gorge', 'alex', 'fib', 'alex'], dtype='object')

# %%
scores.values
# Out:
# array([3.2, 4.5, 2.6, 4. , 3. ])

# %%
d = {'Bob': 4.2,'gorge':4.5,'alex':3.3, "noob": 44}

# %%
s4= pd.Series(d)

# %%
s4
# Out:
# Bob       4.2
# gorge     4.5
# alex      3.3
# noob     44.0
# dtype: float64

# %% [markdown]
# ## DataFrame:

# %%
df1 = pd.DataFrame()
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# RangeIndex(start=0, stop=0, step=1)

# %%
df1.columns
# df1.index
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
students_list = [['bobs',"william",26,'computer engineering',87],
                 ['avi','mollik',22,'CSE', 92],
                 ['alex','black',33,'chemistry',97],
                 ['sarah','smith',23,'EEE',88]]

# %%
students_df=pd.DataFrame(students_list)
students_df
# Out:
#        0        1   2                     3   4
# 0   bobs  william  26  computer engineering  87
# 1    avi   mollik  22                   CSE  92
# 2   alex    black  33             chemistry  97
# 3  sarah    smith  23                   EEE  88

# %%
students_df=pd.DataFrame(students_list,columns=['first_name','last_name','age','Major','score'])
students_df
# Out:
#   first_name last_name  age                 Major  score
# 0       bobs   william   26  computer engineering     87
# 1        avi    mollik   22                   CSE     92
# 2       alex     black   33             chemistry     97
# 3      sarah     smith   23                   EEE     88

# %%
students_df=pd.DataFrame(students_list,columns=['first_name','last_name','age','Major','score'],index=['bob@email.com','emma@email.com','sarah@email.com','alex@email.com'])

# %%
students_df
# Out:
#                 first_name last_name  age                 Major  score
# bob@email.com         bobs   william   26  computer engineering     87
# emma@email.com         avi    mollik   22                   CSE     92
# sarah@email.com       alex     black   33             chemistry     97
# alex@email.com       sarah     smith   23                   EEE     88

# %% [markdown]
# ### convert dictonaires to dataframe

# %%
students_dict = {'first_name':['bobs','avi','alex','sarah'],
                 'last_name':['william','mollik','black','smith'],
                 'age':[26,22,33,23],
                 'Major':['computer engineering','CSE','chemistry','EEE'],
                 'score':[87,92,97,88]}

# %%
student_df2 = pd.DataFrame(students_dict,columns=['last_name','score','city'])
student_df2
# Out:
#   last_name  score city
# 0   william     87  NaN
# 1    mollik     92  NaN
# 2     black     97  NaN
# 3     smith     88  NaN

# %%
students_df.columns
# Out:
# Index(['first_name', 'last_name', 'age', 'Major', 'score'], dtype='object')

# %%
students_df.index
# Out:
# Index(['bob@email.com', 'emma@email.com', 'sarah@email.com', 'alex@email.com'], dtype='object')

# %%
students_df.shape
# Out:
# (4, 5)

# %%
students_df.head(2)
# Out:
#                first_name last_name  age                 Major  score
# bob@email.com        bobs   william   26  computer engineering     87
# emma@email.com        avi    mollik   22                   CSE     92

# %%
students_df.tail(3)
# Out:
#                 first_name last_name  age      Major  score
# emma@email.com         avi    mollik   22        CSE     92
# sarah@email.com       alex     black   33  chemistry     97
# alex@email.com       sarah     smith   23        EEE     88

# %%
students_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, bob@email.com to alex@email.com
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  4 non-null      object
#  1   last_name   4 non-null      object
#  2   age         4 non-null      int64
#  3   Major       4 non-null      object
#  4   score       4 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 364.0+ bytes

# %%
students_df.describe()
# Out:
#              age      score
# count   4.000000   4.000000
# mean   26.000000  91.000000
# std     4.966555   4.546061
# min    22.000000  87.000000
# 25%    22.750000  87.750000
# 50%    24.500000  90.000000
# 75%    27.750000  93.250000
# max    33.000000  97.000000

# %% [markdown]
# ## Read Data from files

# %%
df = pd.read_csv('data_01.csv')
df
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
df2 = pd.read_csv('data_02.csv', header=None,names=['fname','lname','course','score'])
df2
# Out:
#            fname      lname      course  score
# 0          Alex       Smith     Python      92
# 1         James       Jones        C++      97
# 2          Mary    Williams     Python      98
# 3      Patricia       Brown       Java      87
# 4      Jennifer      Taylor       HTML      88
# 5         Emily      Davies   Android       90
# 6       Michael      Wilson     Python      91
# 7       Jessica       Evans        C++      95
# 8          John      Thomas     Python      90
# 9        Thomas     Roberts       Java      89
# 10  Christopher      Martin     Python      83
# 11      Barbara         Lee        C++      86
# 12      Matthew    Anderson          R      97
# 13         Mark       White     Python      91
# 14        Nancy      Taylor       Java      96
# 15       Andrew       Smith          R      92

# %%
df1= pd.read_csv('data_01.csv',skiprows=1,names=['a','b','c','d'])
df1
# Out:
#                a          b           c   d
# 0          Alex       Smith     Python   92
# 1         James       Jones        C++   97
# 2          Mary    Williams     Python   98
# 3      Patricia       Brown       Java   87
# 4      Jennifer      Taylor       HTML   88
# 5         Emily      Davies   Android    90
# 6       Michael      Wilson     Python   91
# 7       Jessica       Evans        C++   95
# 8          John      Thomas     Python   90
# 9        Thomas     Roberts       Java   89
# 10  Christopher      Martin     Python   83
# 11      Barbara         Lee        C++   86
# 12      Matthew    Anderson          R   97
# 13         Mark       White     Python   91
# 14        Nancy      Taylor       Java   96
# 15       Andrew       Smith          R   92

# %%
df3 = pd.read_csv('data_03.csv', sep = '|')
df3
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
df4 = pd.read_csv('data_04.csv', comment='#', sep='\t')
df4
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %%
df5 = pd.read_csv('data_05.csv',skiprows=3)
df5
# Out:
#       first name  last name  experience   score
# 0          Alex       Smith     Python       92
# 1         James       Jones        C++       97
# 2          Mary    Williams     Python       98
# 3      Patricia       Brown       Java       87
# 4      Jennifer      Taylor       HTML       88
# 5         Emily      Davies   Android        90
# 6       Michael      Wilson     Python       91
# 7       Jessica       Evans        C++       95
# 8          John      Thomas     Python       90
# 9        Thomas     Roberts       Java       89
# 10  Christopher      Martin     Python       83
# 11      Barbara         Lee        C++       86
# 12      Matthew    Anderson          R       97
# 13         Mark       White     Python       91
# 14        Nancy      Taylor       Java       96
# 15       Andrew       Smith          R       92

# %% [markdown]
# ## SELECT OPERATION dataframe

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
ages = df['Age']
ages
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
ages.mean()
# Out:
# np.float64(29.69911764705882)

# %%
ages.max()
# Out:
# 80.0

# %%
df[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.iloc[0,[1,4]]
# Out:
# Survived       0
# Sex         male
# Name: 0, dtype: object

# %%
df.loc[0,['Survived','Sex']]
# Out:
# Survived       0
# Sex         male
# Name: 0, dtype: object

# %%
df.iloc[:5,:3]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
df.iloc[[0,-1],-3:]
# Out:
#      Fare Cabin Embarked
# 0    7.25   NaN        S
# 890  7.75   NaN        Q

# %%
df.loc[5:10,'Name':'Ticket']
# Out:
#                                                  Name     Sex   Age  SibSp  \
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch   Ticket
# 5       0   330877
# 6       0    17463
# 7       1   349909
# 8       2   347742
# 9       0   237736
# 10      1  PP 9549

# %%
df.Sex == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df.loc[df.Sex == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.Sex == 'female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df.Age >35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df.loc[(df.Sex == 'female')&(df.Age >35)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 11            12         1       1
# 15            16         1       2
# 25            26         1       3
# 40            41         0       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Handling missing and dublicate data

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df2 = df.dropna(axis=0)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df.shape, df2.shape)
# Out:
# (891, 12) (183, 12)

# %%
df2 = df.fillna(0)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df3 = df.fillna(df.mean(numeric_only=True))
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df4 = df3.fillna(df.mode().iloc[0])
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df4.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df_duplicate = pd.concat((df,df.iloc[:3]))
df_duplicate
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 889          890         1       1
# 890          891         0       3
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Structural Manipulation

# %%
df = pd.read_csv('employees.csv')
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
# df.shape
df.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.Gender
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
df.rename({'First Name': 'First_Name', 'Start Date':'Start_Date', 'Last Login Time':'Last_Login_Time',
       'Bonus %':'Bonus', 'Senior Management':'Senior_Management'}, axis=1)
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df.rename({'First Name': 'First_Name', 'Start Date':'Start_Date', 'Last Login Time':'Last_Login_Time',
       'Bonus %':'Bonus', 'Senior Management':'Senior_Management'}, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['First_Name', 'Gender', 'Start_Date', 'Last_Login_Time', 'Salary',
#        'Bonus', 'Senior_Management', 'Team'],
#       dtype='object')

# %%
df['Bonus2'] = df.Bonus.round()

# %%
df
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team  Bonus2
# 0                True             Marketing     7.0
# 1                True                   NaN     4.0
# ...

# %%
import numpy as np

# %%
df['random'] = pd.Series(np.random.randint(0,10,1000))

# %%
df
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team  Bonus2  random
# 0                True             Marketing     7.0       8
# ...

# %%
df2 = df.iloc[:2]
df2
# Out:
#   First_Name Gender Start_Date Last_Login_Time  Salary  Bonus  \
# 0    Douglas   Male   8/6/1993        12:42 PM   97308  6.945
# 1     Thomas   Male  3/31/1996         6:53 AM   61933  4.170
#
#   Senior_Management       Team  Bonus2  random
# 0              True  Marketing     7.0       8
# 1              True        NaN     4.0       3

# %%
df3 = pd.concat((df,df2),axis=0)
df3
# Out:
#     First_Name  Gender Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...        ...             ...     ...     ...
# 997    Russell    Male  5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949  10.169
# 0      Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933   4.170
#
#     Senior_Management                  Team  Bonus2  random
# 0                True             Marketing     7.0       8
# ...

# %%
df3 = pd.concat((df,df2),axis=0,ignore_index=True)
df3
# Out:
#      First_Name  Gender Start_Date Last_Login_Time  Salary   Bonus  \
# 0       Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1        Thomas    Male  3/31/1996         6:53 AM   61933   4.170
# 2         Maria  Female  4/23/1993        11:17 AM  130590  11.858
# 3         Jerry    Male   3/4/2005         1:00 PM  138705   9.340
# 4         Larry    Male  1/24/1998         4:47 PM  101004   1.389
# ...         ...     ...        ...             ...     ...     ...
# 997     Russell    Male  5/20/2013        12:39 PM   96914   1.421
# 998       Larry    Male  4/20/2013         4:45 PM   60500  11.985
# 999      Albert    Male  5/15/2012         6:24 PM  129949  10.169
# 1000    Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1001     Thomas    Male  3/31/1996         6:53 AM   61933   4.170
#
#      Senior_Management                  Team  Bonus2  random
# 0                 True             Marketing     7.0       8
# ...

# %%
df4 = df.drop(['First_Name'],axis = 1)
df4
# Out:
#      Gender  Start_Date Last_Login_Time  Salary   Bonus Senior_Management  \
# 0      Male    8/6/1993        12:42 PM   97308   6.945              True
# 1      Male   3/31/1996         6:53 AM   61933   4.170              True
# 2    Female   4/23/1993        11:17 AM  130590  11.858             False
# 3      Male    3/4/2005         1:00 PM  138705   9.340              True
# 4      Male   1/24/1998         4:47 PM  101004   1.389              True
# ..      ...         ...             ...     ...     ...               ...
# 995     NaN  11/23/2014         6:09 AM  132483  16.655             False
# 996    Male   1/31/1984         6:30 AM   42392  19.675             False
# 997    Male   5/20/2013        12:39 PM   96914   1.421             False
# 998    Male   4/20/2013         4:45 PM   60500  11.985             False
# 999    Male   5/15/2012         6:24 PM  129949  10.169              True
#
#                      Team  Bonus2  random
# ...

# %%
df5= df.drop(range(5),axis=0)
df5
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 5       Dennis    Male   4/18/1987         1:35 AM  115163  10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476  10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906  11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570  18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852   7.524
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team  Bonus2  random
# 5               False                 Legal    10.0       7
# ...

# %% [markdown]
# ## DATA Transformation

# %%
df = pd.read_csv('employees.csv')

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.Gender.value_counts()
# Out:
# Gender
# Female    431
# Male      424
# Name: count, dtype: int64

# %%
df.Gender.isna().sum()
# Out:
# np.int64(145)

# %%
df['Gender2'] = pd.Categorical(df.Gender)

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2
# 0              True        Marketing    Male
# 1              True              NaN    Male
# 2             False          Finance  Female
# 3              True          Finance    Male
# 4              True  Client Services    Male

# %%
df.memory_usage()
# Out:
# Index                 132
# First Name           8000
# Gender               8000
# Start Date           8000
# Last Login Time      8000
# Salary               8000
# Bonus %              8000
# Senior Management    8000
# Team                 8000
# Gender2              1124
# dtype: int64

# %%
import random

# %%
df['score'] = random.choices(['Very Low','Low','Medium','High','Very High'],k=1000)

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2   score
# 0              True        Marketing    Male     Low
# 1              True              NaN    Male    High
# 2             False          Finance  Female  Medium
# 3              True          Finance    Male     Low
# 4              True  Client Services    Male  Medium

# %%
df.dtypes
# Out:
# First Name             object
# Gender                 object
# Start Date             object
# Last Login Time        object
# Salary                  int64
# Bonus %               float64
# Senior Management      object
# Team                   object
# Gender2              category
# score                  object
# dtype: object

# %%
df['Score2']=pd.Categorical(df.score,categories=['Very Low','Low','Medium','High','Very High'],ordered=True)

# %%
sum(df.Score2>'Medium')
# Out:
# 393

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2   score  Score2
# 0              True        Marketing    Male     Low     Low
# 1              True              NaN    Male    High    High
# 2             False          Finance  Female  Medium  Medium
# 3              True          Finance    Male     Low     Low
# 4              True  Client Services    Male  Medium  Medium

# %%
df.Salary.min()
# Out:
# 35013

# %%
df.Salary.max()
# Out:
# 149908

# %%
df['cat_salary']=pd.cut(df.Salary,bins=[35000,50000,75000,100000,125000,150000], labels=['Very Low','Low','Medium','High','Very High'])

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team Gender2     score    Score2  \
# 0                True             Marketing    Male       Low       Low
# ...

# %%
df.memory_usage()
# Out:
# Index                 132
# First Name           8000
# Gender               8000
# Start Date           8000
# Last Login Time      8000
# Salary               8000
# Bonus %              8000
# Senior Management    8000
# Team                 8000
# Gender2              1124
# score                8000
# Score2               1212
# cat_salary           1212
# dtype: int64
